# %%
from GaussElim import GaussElim

# %%
xyz=[[1,-1,1,9],[1,1,1,5],[4,2,1,12]]
X=GaussElim(xyz)
print(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-29f4a149503a> in <module>
#       1 xyz=[[1,-1,1,9],[1,1,1,5],[4,2,1,12]]
# ----> 2 X=GaussElim(xyz)
#       3 print(X)
#
# NameError: name 'GaussElim' is not defined
